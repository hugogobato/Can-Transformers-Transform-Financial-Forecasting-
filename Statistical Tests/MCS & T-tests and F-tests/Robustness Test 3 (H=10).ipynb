# %%
import pandas as pd
import numpy as np

# %%
import numpy as np
import scipy

def f_test(x, y):
    x = np.array(x)
    y = np.array(y)
    variance1=np.var(x, ddof=1)
    variance2=np.var(y, ddof=1)
    # Ensuring the larger variance is the numerator
    if variance1 > variance2:
      f_value = variance1 / variance2
      df1 = len(x) - 1  # degrees of freedom for x
      df2 = len(y) - 1  # degrees of freedom for y
    else:
      f_value = variance2 / variance1
      df1 = len(y) - 1  # degrees of freedom for y
      df2 = len(x) - 1  # degrees of freedom for x
    p = 1-scipy.stats.f.cdf(f_value, df1, df2) #find p-value of F test statistic
    return f_value, p

# %%
NBEATSx=pd.read_excel("NBEATSx forecasts.xlsx", index_col="Unnamed: 0")

# %%
NHITS=pd.read_excel("NHITS forecasts.xlsx", index_col="Unnamed: 0")

# %%
TFT=pd.read_excel("TFT forecasts.xlsx", index_col="Unnamed: 0")

# %%
TimesNet=pd.read_excel("TimesNet forecasts.xlsx", index_col="Unnamed: 0")

# %%
Autoformer=pd.read_excel("Autoformer forecasts.xlsx", index_col="Unnamed: 0")

# %%
Informer=pd.read_excel("Informer forecasts.xlsx", index_col="Unnamed: 0")

# %%
PatchTST=pd.read_excel("PatchTST forecasts.xlsx", index_col="Unnamed: 0")

# %% [markdown]
# # Results

# %%
models = [NHITS,NBEATSx,TFT, TimesNet, Autoformer, Informer, PatchTST]
models_names = ["NHITS","NBEATSx","TFT", "TimesNet", "Autoformer", "Informer", "PatchTST "]
for j in range(len(models)):
  print(f"{models_names[j]}")
  for i in range(len(NBEATSx.columns)):
    print(f"Mean of {models[j].columns[i]}: {round(100*models[j][models[j].columns[i]].mean(),3)}%")
    print(f"Standard Deviation of {models[j].columns[i]}: {round(100*models[j][models[j].columns[i]].std(),3)}%")
# Out:
# NHITS
# Mean of RMSE: 0.565%
# Standard Deviation of RMSE: 0.004%
# Mean of QLIKE: 5.958%
# Standard Deviation of QLIKE: 0.106%
# Mean of MAE: 0.329%
# Standard Deviation of MAE: 0.002%
# Mean of MAPE: 23.831%
# Standard Deviation of MAPE: 0.281%
# NBEATSx
# Mean of RMSE: 0.563%
# Standard Deviation of RMSE: 0.003%
# Mean of QLIKE: 5.915%
# Standard Deviation of QLIKE: 0.062%
# Mean of MAE: 0.328%
# Standard Deviation of MAE: 0.001%
# Mean of MAPE: 23.684%
# Standard Deviation of MAPE: 0.156%
# TFT
# Mean of RMSE: 0.577%
# Standard Deviation of RMSE: 0.004%
# Mean of QLIKE: 5.753%
# Standard Deviation of QLIKE: 0.078%
# Mean of MAE: 0.353%
# Standard Deviation of MAE: 0.008%
# Mean of MAPE: 26.918%
# Standard Deviation of MAPE: 1.168%
# TimesNet
# Mean of RMSE: 0.575%
# Standard Deviation of RMSE: 0.006%
# Mean of QLIKE: 5.706%
# Standard Deviation of QLIKE: 0.047%
# Mean of MAE: 0.35%
# Standard Deviation of MAE: 0.005%
# Mean of MAPE: 26.671%
# Standard Deviation of MAPE: 0.638%
# Autoformer
# Mean of RMSE: 0.573%
# Standard Deviation of RMSE: 0.005%
# Mean of QLIKE: 6.067%
# Standard Deviation of QLIKE: 0.051%
# Mean of MAE: 0.336%
# Standard Deviation of MAE: 0.002%
# Mean of MAPE: 24.519%
# Standard Deviation of MAPE: 0.118%
# Informer
# Mean of RMSE: 0.57%
# Standard Deviation of RMSE: 0.002%
# Mean of QLIKE: 6.041%
# Standard Deviation of QLIKE: 0.05%
# Mean of MAE: 0.329%
# Standard Deviation of MAE: 0.001%
# Mean of MAPE: 23.287%
# Standard Deviation of MAPE: 0.121%
# PatchTST
# Mean of RMSE: 0.549%
# Standard Deviation of RMSE: 0.001%
# Mean of QLIKE: 5.595%
# Standard Deviation of QLIKE: 0.02%
# Mean of MAE: 0.338%
# Standard Deviation of MAE: 0.001%
# Mean of MAPE: 25.76%
# Standard Deviation of MAPE: 0.074%

# %% [markdown]
# # Autoformer

# %% [markdown]
# T-tests

# %%
from scipy import stats
models = [NHITS,NBEATSx,TFT, TimesNet, Informer, PatchTST]
models_names = ["NHITS","NBEATSx","TFT", "TimesNet", "Informer", "PatchTST "]
for j in range(len(models)):
  print(f"{models_names[j]}")
  for i in range(len(NBEATSx.columns)):
    print(f"{models[j].columns[i]}: {stats.ttest_ind(models[j][models[j].columns[i]], Autoformer[models[j].columns[i]])}")
# Out:
# NHITS
# RMSE: TtestResult(statistic=-5.925721658955713, pvalue=7.198319054375426e-07, df=38.0)
# QLIKE: TtestResult(statistic=-4.164592083750417, pvalue=0.00017276031887502832, df=38.0)
# MAE: TtestResult(statistic=-12.385811643626953, pvalue=6.504720158163824e-15, df=38.0)
# MAPE: TtestResult(statistic=-10.106142126864047, pvalue=2.54377395779671e-12, df=38.0)
# NBEATSx
# RMSE: TtestResult(statistic=-7.944860361469801, pvalue=1.3462481313228253e-09, df=38.0)
# QLIKE: TtestResult(statistic=-8.484328467756518, pvalue=2.668798763920564e-10, df=38.0)
# MAE: TtestResult(statistic=-16.866085998238127, pvalue=3.0881761498237315e-19, df=38.0)
# MAPE: TtestResult(statistic=-19.114238198927023, pvalue=4.339108162426168e-21, df=38.0)
# TFT
# RMSE: TtestResult(statistic=2.953058202115859, pvalue=0.005371579970480101, df=38.0)
# QLIKE: TtestResult(statistic=-15.051737118704073, pvalue=1.3463269002280333e-17, df=38.0)
# MAE: TtestResult(statistic=9.312158178767229, pvalue=2.3812771596960383e-11, df=38.0)
# MAPE: TtestResult(statistic=9.144035939107708, pvalue=3.8634680728641314e-11, df=38.0)
# TimesNet
# RMSE: TtestResult(statistic=1.2882046298234413, pvalue=0.20546379649049268, df=38.0)
# QLIKE: TtestResult(statistic=-23.34351116736483, pvalue=3.912014987234401e-24, df=38.0)
# MAE: TtestResult(statistic=11.257526016285695, pvalue=1.1482850999447394e-13, df=38.0)
# MAPE: TtestResult(statistic=14.837906212002911, pvalue=2.146834255544369e-17, df=38.0)
# Informer
# RMSE: TtestResult(statistic=-2.211017099070097, pvalue=0.03312598166002387, df=38.0)
# QLIKE: TtestResult(statistic=-1.654010610333445, pvalue=0.1063639338273338, df=38.0)
# MAE: TtestResult(statistic=-17.19656131223211, pvalue=1.6056119482755946e-19, df=38.0)
# MAPE: TtestResult(statistic=-32.66904587141847, pvalue=2.0249646994449388e-29, df=38.0)
# PatchTST
# RMSE: TtestResult(statistic=-22.67069718650078, pvalue=1.1053948255171941e-23, df=38.0)
# QLIKE: TtestResult(statistic=-38.653837732474024, pvalue=4.070982796215252e-32, df=38.0)
# MAE: TtestResult(statistic=5.363705367767322, pvalue=4.242069748750071e-06, df=38.0)
# MAPE: TtestResult(statistic=39.93291610485657, pvalue=1.216265014238695e-32, df=38.0)

# %% [markdown]
# F-tests

# %%
models = [NHITS,NBEATSx,TFT, TimesNet, Informer, PatchTST]
models_names = ["NHITS","NBEATSx","TFT", "TimesNet", "Informer", "PatchTST "]
for j in range(len(models)):
  print(f"{models_names[j]}")
  for i in range(len(NBEATSx.columns)):
    print(f"{models[j].columns[i]}: {f_test(models[j][models[j].columns[i]], Autoformer[models[j].columns[i]])}")
# Out:
# NHITS
# RMSE: (1.272264525651349, 0.30246091394682284)
# QLIKE: (4.291522998145501, 0.0013028589851923345)
# MAE: (1.5370524080059587, 0.1784844988652936)
# MAPE: (5.7021122228626195, 0.0001969099602658897)
# NBEATSx
# RMSE: (2.0658861652728824, 0.06126330049816253)
# QLIKE: (1.4829633271532539, 0.19908524362169622)
# MAE: (1.387129390793865, 0.24123451775222338)
# MAPE: (1.7575409609090034, 0.11406719054809034)
# TFT
# RMSE: (1.4394762953677516, 0.21727363473811978)
# QLIKE: (2.351799599529202, 0.03492332224951267)
# MAE: (25.69970832823758, 9.91918658321822e-10)
# MAPE: (98.55504371867308, 4.551914400963142e-15)
# TimesNet
# RMSE: (1.770033282487121, 0.11120976683073658)
# QLIKE: (1.190106065807252, 0.3541545512809703)
# MAE: (11.476167297950457, 9.671757295048877e-07)
# MAPE: (29.4075315508667, 2.9900915077263335e-10)
# Informer
# RMSE: (3.4527791811440482, 0.004828346204556744)
# QLIKE: (1.034417653198286, 0.4709889039026369)
# MAE: (2.4313365007643886, 0.029964531236368885)
# MAPE: (1.0560730370596774, 0.4532936413710402)
# PatchTST
# RMSE: (12.572333074998722, 4.583154286086355e-07)
# QLIKE: (6.8277392105782075, 5.428487849601371e-05)
# MAE: (3.735219879024066, 0.003051305758836831)
# MAPE: (2.5136214691114316, 0.025615033105870877)

# %% [markdown]
# # Informer

# %%
from scipy import stats
models = [NHITS,NBEATSx,TFT, TimesNet, Autoformer, PatchTST]
models_names = ["NHITS","NBEATSx","TFT", "TimesNet", "Autoformer", "PatchTST "]
for j in range(len(models)):
  print(f"{models_names[j]}")
  for i in range(len(NBEATSx.columns)):
    print(f"{models[j].columns[i]}: {stats.ttest_ind(models[j][models[j].columns[i]], Informer[models[j].columns[i]])}")
# Out:
# NHITS
# RMSE: TtestResult(statistic=-5.214765745039517, pvalue=6.775598328272587e-06, df=38.0)
# QLIKE: TtestResult(statistic=-3.166191812976455, pvalue=0.0030405648223300824, df=38.0)
# MAE: TtestResult(statistic=0.5021317927911751, pvalue=0.6184721767197406, df=38.0)
# MAPE: TtestResult(statistic=7.95528521914131, pvalue=1.3044048189233327e-09, df=38.0)
# NBEATSx
# RMSE: TtestResult(statistic=-8.148929738690107, pvalue=7.271349828911479e-10, df=38.0)
# QLIKE: TtestResult(statistic=-7.059730247637295, pvalue=2.042058851019213e-08, df=38.0)
# MAE: TtestResult(statistic=-1.5942485903868442, pvalue=0.11916521867290396, df=38.0)
# MAPE: TtestResult(statistic=9.004132991824555, pvalue=5.794840462024959e-11, df=38.0)
# TFT
# RMSE: TtestResult(statistic=6.405593346856104, pvalue=1.5836071281552135e-07, df=38.0)
# QLIKE: TtestResult(statistic=-13.853684996284679, pvalue=1.9591110591372512e-16, df=38.0)
# MAE: TtestResult(statistic=13.414514442459446, pvalue=5.44085703911717e-16, df=38.0)
# MAPE: TtestResult(statistic=13.835015858378506, pvalue=2.0451382924324514e-16, df=38.0)
# TimesNet
# RMSE: TtestResult(statistic=3.2434781915194875, pvalue=0.002462783599937155, df=38.0)
# QLIKE: TtestResult(statistic=-21.831875203676173, pvalue=4.192331951210693e-23, df=38.0)
# MAE: TtestResult(statistic=17.458153816167055, pvalue=9.633498895274312e-20, df=38.0)
# MAPE: TtestResult(statistic=23.311456652648076, pvalue=4.108037336904476e-24, df=38.0)
# Autoformer
# RMSE: TtestResult(statistic=2.211017099070097, pvalue=0.03312598166002387, df=38.0)
# QLIKE: TtestResult(statistic=1.654010610333445, pvalue=0.1063639338273338, df=38.0)
# MAE: TtestResult(statistic=17.19656131223211, pvalue=1.6056119482755946e-19, df=38.0)
# MAPE: TtestResult(statistic=32.66904587141847, pvalue=2.0249646994449388e-29, df=38.0)
# PatchTST
# RMSE: TtestResult(statistic=-34.63571062001385, pvalue=2.356492805856376e-30, df=38.0)
# QLIKE: TtestResult(statistic=-37.028756156698186, pvalue=1.9982623318748044e-31, df=38.0)
# MAE: TtestResult(statistic=32.12076647897198, pvalue=3.768947772920213e-29, df=38.0)
# MAPE: TtestResult(statistic=78.0049922912596, pvalue=1.493966911427226e-43, df=38.0)

# %%
models = [NHITS,NBEATSx,TFT, TimesNet, Autoformer, PatchTST]
models_names = ["NHITS","NBEATSx","TFT", "TimesNet", "Autoformer", "PatchTST "]
for j in range(len(models)):
  print(f"{models_names[j]}")
  for i in range(len(NBEATSx.columns)):
    print(f"{models[j].columns[i]}: {f_test(models[j][models[j].columns[i]], Informer[models[j].columns[i]])}")
# Out:
# NHITS
# RMSE: (2.713884661192107, 0.017610748387939856)
# QLIKE: (4.4392271483881425, 0.0010508727961651143)
# MAE: (3.737091623172685, 0.003042230052584527)
# MAPE: (5.3993540434840215, 0.00028708039795632967)
# NBEATSx
# RMSE: (1.6713308018537272, 0.13591007722959436)
# QLIKE: (1.534003444652991, 0.1795889812763477)
# MAE: (1.7527827734750219, 0.11517498429728745)
# MAPE: (1.6642229270452316, 0.1378879127829411)
# TFT
# RMSE: (2.398635665106209, 0.0319060544398726)
# QLIKE: (2.4327430225376663, 0.02988389719412854)
# MAE: (62.48463891744257, 3.140820936664568e-13)
# MAPE: (93.32218536046562, 7.549516567451064e-15)
# TimesNet
# RMSE: (6.111534067703594, 0.00012084417759405941)
# QLIKE: (1.1505082711297485, 0.3815345495831812)
# MAE: (27.902424440385573, 4.777968021230095e-10)
# MAPE: (27.846115295911034, 4.864708635921033e-10)
# Autoformer
# RMSE: (3.4527791811440482, 0.004828346204556744)
# QLIKE: (1.034417653198286, 0.4709889039026369)
# MAE: (2.4313365007643886, 0.029964531236368885)
# MAPE: (1.0560730370596774, 0.4532936413710402)
# PatchTST
# RMSE: (3.6412212931708505, 0.003547388346324065)
# QLIKE: (6.60056331160602, 6.948638910497795e-05)
# MAE: (1.5362825663373822, 0.1787627508871763)
# MAPE: (2.6545678589029174, 0.019656919425612207)

# %% [markdown]
# # PatchTST

# %%
from scipy import stats
models = [NHITS,NBEATSx,TFT, TimesNet, Autoformer, Informer]
models_names = ["NHITS","NBEATSx","TFT", "TimesNet", "Autoformer", "Informer"]
for j in range(len(models)):
  print(f"{models_names[j]}")
  for i in range(len(NBEATSx.columns)):
    print(f"{models[j].columns[i]}: {stats.ttest_ind(models[j][models[j].columns[i]], PatchTST[models[j].columns[i]])}")
# Out:
# NHITS
# RMSE: TtestResult(statistic=16.806523114998495, pvalue=3.478214346831185e-19, df=38.0)
# QLIKE: TtestResult(statistic=15.098769183649193, pvalue=1.2157835461932413e-17, df=38.0)
# MAE: TtestResult(statistic=-19.180498475498332, pvalue=3.8505297917076145e-21, df=38.0)
# MAPE: TtestResult(statistic=-29.709166262696076, pvalue=6.547996427086296e-28, df=38.0)
# NBEATSx
# RMSE: TtestResult(statistic=18.484030295666493, pvalue=1.3749658173424877e-20, df=38.0)
# QLIKE: TtestResult(statistic=21.94980173927701, pvalue=3.466742053376064e-23, df=38.0)
# MAE: TtestResult(statistic=-28.32612244732805, pvalue=3.712635854819657e-27, df=38.0)
# MAPE: TtestResult(statistic=-53.77866544649208, pvalue=1.8066706018910808e-37, df=38.0)
# TFT
# RMSE: TtestResult(statistic=31.138923560757714, pvalue=1.1756039673626904e-28, df=38.0)
# QLIKE: TtestResult(statistic=8.750661782948269, pvalue=1.2153523938796257e-10, df=38.0)
# MAE: TtestResult(statistic=8.257425918411844, pvalue=5.25045101976998e-10, df=38.0)
# MAPE: TtestResult(statistic=4.425634566554191, pvalue=7.836952505117244e-05, df=38.0)
# TimesNet
# RMSE: TtestResult(statistic=18.896513891961867, pvalue=6.4403916638087654e-21, df=38.0)
# QLIKE: TtestResult(statistic=9.786055805593184, pvalue=6.205987199421209e-12, df=38.0)
# MAE: TtestResult(statistic=9.840930929163132, pvalue=5.321049837246888e-12, df=38.0)
# MAPE: TtestResult(statistic=6.339130336468663, pvalue=1.9523723907939823e-07, df=38.0)
# Autoformer
# RMSE: TtestResult(statistic=22.67069718650078, pvalue=1.1053948255171941e-23, df=38.0)
# QLIKE: TtestResult(statistic=38.653837732474024, pvalue=4.070982796215252e-32, df=38.0)
# MAE: TtestResult(statistic=-5.363705367767322, pvalue=4.242069748750071e-06, df=38.0)
# MAPE: TtestResult(statistic=-39.93291610485657, pvalue=1.216265014238695e-32, df=38.0)
# Informer
# RMSE: TtestResult(statistic=34.63571062001385, pvalue=2.356492805856376e-30, df=38.0)
# QLIKE: TtestResult(statistic=37.028756156698186, pvalue=1.9982623318748044e-31, df=38.0)
# MAE: TtestResult(statistic=-32.12076647897198, pvalue=3.768947772920213e-29, df=38.0)
# MAPE: TtestResult(statistic=-78.0049922912596, pvalue=1.493966911427226e-43, df=38.0)

# %%
models = [NHITS,NBEATSx,TFT, TimesNet, Autoformer, Informer]
models_names = ["NHITS","NBEATSx","TFT", "TimesNet", "Autoformer", "Informer"]
for j in range(len(models)):
  print(f"{models_names[j]}")
  for i in range(len(NBEATSx.columns)):
    print(f"{models[j].columns[i]}: {f_test(models[j][models[j].columns[i]], PatchTST[models[j].columns[i]])}")
# Out:
# NHITS
# RMSE: (9.88185461554246, 3.2162092136189813e-06)
# QLIKE: (29.301399847536185, 3.088262978678813e-10)
# MAE: (5.741228709485665, 0.0001877391831964781)
# MAPE: (14.332951702670188, 1.5414741805219734e-07)
# NBEATSx
# RMSE: (6.085685303642103, 0.00012454029685149415)
# QLIKE: (10.125286856653789, 2.6505254820952118e-06)
# MAE: (2.6927696174661615, 0.018311605173150336)
# MAPE: (4.417792692183607, 0.0010838723236067382)
# TFT
# RMSE: (8.733963258343753, 8.46996786307841e-06)
# QLIKE: (16.05747434112766, 5.90768346464543e-08)
# MAE: (95.99406143275334, 5.88418203051333e-15)
# MAPE: (247.7300737804724, 1.1102230246251565e-16)
# TimesNet
# RMSE: (22.253447981261388, 3.527533931624305e-09)
# QLIKE: (5.737084623585154, 0.00018868814242611887)
# MAE: (42.86600822631044, 9.960809954634442e-12)
# MAPE: (73.91940265983034, 6.639133687258436e-14)
# Autoformer
# RMSE: (12.572333074998722, 4.583154286086355e-07)
# QLIKE: (6.8277392105782075, 5.428487849601371e-05)
# MAE: (3.735219879024066, 0.003051305758836831)
# MAPE: (2.5136214691114316, 0.025615033105870877)
# Informer
# RMSE: (3.6412212931708505, 0.003547388346324065)
# QLIKE: (6.60056331160602, 6.948638910497795e-05)
# MAE: (1.5362825663373822, 0.1787627508871763)
# MAPE: (2.6545678589029174, 0.019656919425612207)

# %% [markdown]
# # TFT

# %%
from scipy import stats
models = [NHITS,NBEATSx,PatchTST, TimesNet, Autoformer, Informer]
models_names = ["NHITS","NBEATSx","PatchTST", "TimesNet", "Autoformer", "Informer"]
for j in range(len(models)):
  print(f"{models_names[j]}")
  for i in range(len(NBEATSx.columns)):
    print(f"{models[j].columns[i]}: {stats.ttest_ind(models[j][models[j].columns[i]], TFT[models[j].columns[i]])}")
# Out:
# NHITS
# RMSE: TtestResult(statistic=-9.667276529842294, pvalue=8.669821333995696e-12, df=38.0)
# QLIKE: TtestResult(statistic=6.974552428206416, pvalue=2.6622232285691375e-08, df=38.0)
# MAE: TtestResult(statistic=-13.000064019890901, pvalue=1.4561580999678024e-15, df=38.0)
# MAPE: TtestResult(statistic=-11.497803138415348, pvalue=6.147069546915156e-14, df=38.0)
# NBEATSx
# RMSE: TtestResult(statistic=-12.455409301122767, pvalue=5.4774581105210805e-15, df=38.0)
# QLIKE: TtestResult(statistic=7.2449637189713965, pvalue=1.1492854106453824e-08, df=38.0)
# MAE: TtestResult(statistic=-13.66570793880314, pvalue=3.025265908071144e-16, df=38.0)
# MAPE: TtestResult(statistic=-12.278575092369767, pvalue=8.487021436610011e-15, df=38.0)
# PatchTST
# RMSE: TtestResult(statistic=-31.138923560757714, pvalue=1.1756039673626904e-28, df=38.0)
# QLIKE: TtestResult(statistic=-8.750661782948269, pvalue=1.2153523938796257e-10, df=38.0)
# MAE: TtestResult(statistic=-8.257425918411844, pvalue=5.25045101976998e-10, df=38.0)
# MAPE: TtestResult(statistic=-4.425634566554191, pvalue=7.836952505117244e-05, df=38.0)
# TimesNet
# RMSE: TtestResult(statistic=-1.0830272030627264, pvalue=0.2856208520889005, df=38.0)
# QLIKE: TtestResult(statistic=-2.3005977237308923, pvalue=0.026995389687827366, df=38.0)
# MAE: TtestResult(statistic=-1.3701623250440647, pvalue=0.17867744683879855, df=38.0)
# MAPE: TtestResult(statistic=-0.8323859478662815, pvalue=0.4103920227620137, df=38.0)
# Autoformer
# RMSE: TtestResult(statistic=-2.953058202115859, pvalue=0.005371579970480101, df=38.0)
# QLIKE: TtestResult(statistic=15.051737118704073, pvalue=1.3463269002280333e-17, df=38.0)
# MAE: TtestResult(statistic=-9.312158178767229, pvalue=2.3812771596960383e-11, df=38.0)
# MAPE: TtestResult(statistic=-9.144035939107708, pvalue=3.8634680728641314e-11, df=38.0)
# Informer
# RMSE: TtestResult(statistic=-6.405593346856104, pvalue=1.5836071281552135e-07, df=38.0)
# QLIKE: TtestResult(statistic=13.853684996284679, pvalue=1.9591110591372512e-16, df=38.0)
# MAE: TtestResult(statistic=-13.414514442459446, pvalue=5.44085703911717e-16, df=38.0)
# MAPE: TtestResult(statistic=-13.835015858378506, pvalue=2.0451382924324514e-16, df=38.0)

# %%
models = [NHITS,NBEATSx,PatchTST, TimesNet, Autoformer, Informer]
models_names = ["NHITS","NBEATSx","PatchTST", "TimesNet", "Autoformer", "Informer"]
for j in range(len(models)):
  print(f"{models_names[j]}")
  for i in range(len(NBEATSx.columns)):
    print(f"{models[j].columns[i]}: {f_test(models[j][models[j].columns[i]], TFT[models[j].columns[i]])}")
# Out:
# NHITS
# RMSE: (1.1314284618843686, 0.3953040308343265)
# QLIKE: (1.8247826043531112, 0.0995188157221677)
# MAE: (16.72012495759868, 4.1866383138078334e-08)
# MAPE: (17.28395371166436, 3.1530419053460434e-08)
# NBEATSx
# RMSE: (1.435165116592002, 0.21915978959948312)
# QLIKE: (1.5858784613668064, 0.16167120060605011)
# MAE: (35.64882075692822, 5.3042792380608716e-11)
# MAPE: (56.07553161532021, 8.514300375850326e-13)
# PatchTST
# RMSE: (8.733963258343753, 8.46996786307841e-06)
# QLIKE: (16.05747434112766, 5.90768346464543e-08)
# MAE: (95.99406143275334, 5.88418203051333e-15)
# MAPE: (247.7300737804724, 1.1102230246251565e-16)
# TimesNet
# RMSE: (2.547920952152182, 0.0240057908104373)
# QLIKE: (2.7988909689627697, 0.015067667185454936)
# MAE: (2.239398194624378, 0.043469136014648746)
# MAPE: (3.3513538376453247, 0.005720132151461166)
# Autoformer
# RMSE: (1.4394762953677516, 0.21727363473811978)
# QLIKE: (2.351799599529202, 0.03492332224951267)
# MAE: (25.69970832823758, 9.91918658321822e-10)
# MAPE: (98.55504371867308, 4.551914400963142e-15)
# Informer
# RMSE: (2.398635665106209, 0.0319060544398726)
# QLIKE: (2.4327430225376663, 0.02988389719412854)
# MAE: (62.48463891744257, 3.140820936664568e-13)
# MAPE: (93.32218536046562, 7.549516567451064e-15)
